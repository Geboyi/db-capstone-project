# %%
import mysql.connector as connector

# %%
connection=connector.connect(username="little_lemon", password="littlelemon@2", db="littlelemondb")

# %%
cursor=connection.cursor()

# %%
show_tables_query = "SHOW tables"
cursor.execute(show_tables_query)

# %%
results=cursor.fetchall()

# %%
for result in results:
    print(result)
# Out:
# ('bookings',)
# ('customer',)
# ('deliverystatus',)
# ('menu',)
# ('menuitems',)
# ('orders',)
# ('ordersview',)
# ('staff',)

# %%
query_a = "SELECT orders.TotalCost, customer.CustomerName, customer.City FROM orders JOIN customer ON orders.CustomerID=customer.CustomerID WHERE orders.TotalCost>60 ORDER BY orders.TotalCost ASC;"

# %%
cursor.execute(query_a)

# %%
query_result=cursor.fetchall()

# %%
for query_r in query_result:
    print(query_r)
# Out:
# (66.855, 'Anna-maria Neilan', 'Nong Saeng')
# (66.855, 'Fawnia Bartosch', 'Kh?ndb?ri')
# (66.855, 'Hermione Tire', 'Amparo')
# (66.855, 'Steffane Karpol', 'Vólos')
# (66.855, 'Karia Sonier', 'Wuxue Shi')
# (66.855, 'Cynthy Stovold', 'Budapest')
# (66.855, 'Ives Darmody', 'Jiangkou')
# (66.855, 'Reggie Hallaways', 'Zhongluotan')
# (66.855, 'Porty Auston', 'Yanshang')
# (66.855, 'Cahra Delacoste', 'Zhouhe')
# (66.855, 'Anatole Desforges', 'Wassa-Akropong')
# (66.855, 'Teriann Olivari', 'Assiniboia')
# (66.855, 'Hulda Nayshe', 'Krajan Kedungsalam')
# (66.855, 'Bambie Frears', 'Zhanjiang')
# (66.855, 'Nadean Elves', 'Pardubice')
# (66.855, 'Dominga Mc Kellen', 'Kochenëvo')
# (66.855, 'Joycelin Loghan', 'Duqu')
# (66.855, 'Charil Fanton', 'Clifden')
# (66.855, 'Jozef Godson', 'Forquilhinha')
# (66.855, 'George Woodeson', 'Cartagena')
# (66.855, 'Sorcha Beesley', 'Zabrat')
# (66.855, 'Florella Reape', 'Lérida')
# (66.855, 'Brynn Roset', 'Trujillo')
# ...
